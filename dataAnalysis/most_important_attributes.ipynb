# %%
import pandas as pd
import numpy as np

data = np.array(pd.read_csv('../data/data_description.csv'))[:,[1,4]]
sorted_data = data[data[:, 1].argsort()[::-1]]

for index, (value1, value2) in enumerate(sorted_data):
    print(f"{index}, {value1}, {value2}")
# Out:
# 0, persoon_leeftijd_bij_onderzoek, 100.0
# 1, relatie_overig_actueel_vorm__kostendeler, 35.48567371
# 2, contacten_onderwerp_no_show, 27.87480154
# 3, competentie_vakdeskundigheid_toepassen, 25.10663325
# 4, contacten_onderwerp_overleg_met_inkomen, 24.10136742
# 5, adres_dagen_op_adres, 23.3291412
# 6, relatie_overig_kostendeler, 20.74894957
# 7, pla_historie_ontwikkeling, 19.11129497
# 8, instrument_ladder_huidig_activering, 17.5047868
# 9, contacten_soort_afgelopenjaar_document__uitgaand_, 15.41383527
# 10, persoonlijke_eigenschappen_dagen_sinds_taaleis, 15.15384566
# 11, persoonlijke_eigenschappen_dagen_sinds_opvoer, 14.928516
# 12, ontheffing_dagen_hist_vanwege_uw_medische_omstandigheden, 13.817025
# 13, relatie_partner_totaal_dagen_partner, 12.44248405
# 14, pla_hist_pla_categorie_doelstelling_16, 11.93466823
# 15, relatie_kind_leeftijd_verschil_ouder_eerste_kind, 11.16591537
# 16, relatie_kind_huidige_aantal, 10.84799741
# 17, instrument_ladder_historie_activering, 10.76043283
# ...
